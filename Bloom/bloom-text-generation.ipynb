# %%
# !pip install einops
# Out:
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 646.8 kB/s eta 0:00:000:00:01
# Installing collected packages: einops
# Successfully installed einops-0.7.0

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-560m")
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-560m")
# Out:
# tokenizer_config.json:   0%|          | 0.00/222 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/693 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]

# %% [markdown]
# ## Generate Research Book Name

# %%
def generate_titles(query):
    prompt = f"Generate 3 Short, Unqiue and Good Legal Research title names on the legal query -'{query}'"
    inputs = tokenizer(prompt, return_tensors="pt", return_attention_mask=False)
    outputs = model.generate(**inputs, max_length=100)
    return tokenizer.batch_decode(outputs)[0]

# %%
query="Siblings Murder"
#query="Cheque Bounce"
#query=input("Enter the query: ")

# %%
print(generate_titles(query))
# Out:
# Generate 3 Short, Unqiue and Good Legal Research title names on the legal query -'Siblings Murder', 'Child Abuse', 'Child Sexual Abuse' and 'Child Sexual Exploitation'. The legal research title names are not the legal research title names of the legal research title names of the legal research title names of the legal research title names of the legal research title names of the legal research title names of the legal research title names of the legal research title names of the

# %% [markdown]
# ## Facts Enhancement

# %%
fact='Loan pending with the bank'
prompt = f"Enhance the fact -'{fact}' legally by adding 2-3 words"
inputs = tokenizer(prompt, return_tensors="pt")
outputs = model.generate(**inputs, max_length=100)
tokenizer.batch_decode(outputs)[0]
# Out:
# "Enhance the fact -'Loan pending with the bank' legally by adding 2-3 words to the end of the loan. This will make it easier for the bank to understand the loan and the loaner to understand the loan. The loaner will be able to understand the loan and the loaner will be able to understand the loan. The loaner will be able to understand the loan and the loaner will be able to understand the loan. The loaner will be able to understand the loan"
