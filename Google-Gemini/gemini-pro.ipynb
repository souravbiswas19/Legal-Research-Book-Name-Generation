# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai
GOOGLE_API_KEY="AIzaSyB2lvqmczsT7Bc8yCJl-KRzPT3VCQMt24A"
genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %% [markdown]
# ## Generate Research Book Name

# %%
query="Cheque Bounce"
prompt = f"Generate 3 Short, Unqiue and Good Legal Research title names with the query -'{query}'"
response = model.generate_content(prompt)
# Out:
# '1. The Repercussions of Dishonored Cheques: A Legal Analysis\n2. Legal Consequences of Issuing Bounced Cheques: Exploring the Ambit of Liability\n3. Statutory and Case Law Framework Governing Cheque Bounce: A Comprehensive Oview'

# %%
print(response.text)
# Out:
# 1. The Repercussions of Dishonored Cheques: A Legal Analysis
# 2. Legal Consequences of Issuing Bounced Cheques: Exploring the Ambit of Liability
# 3. Statutory and Case Law Framework Governing Cheque Bounce: A Comprehensive Oview

# %% [markdown]
# ## Enhancing of Facts

# %%
fact='Loan pending with the bank'
prompt = f"Enhanced legal version of the fact -'{fact}' with the addition of 2-5 words."
enh_fact = model.generate_content(prompt)

# %%
print(enh_fact.text)
# Out:
# Loan application is pending with the bank for approval.
