# %%
access_token="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"
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf", token=access_token)
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-2-7b-chat-hf", token=access_token)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %% [markdown]
# ## Generate Research Book Name

# %%
#query="Siblings Murder"
query="Cheque Bounce"
#query=input("Enter the query: ")
def generate_titles(query):
    prompt = f"Generate 3 Short, Unqiue and Good Legal Research title names with the query -'{query}'"
    inputs = tokenizer(prompt, return_tensors="pt")
    generate_ids = model.generate(inputs.input_ids, max_length=150)
    return tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

# %%
print(generate_titles(query))
# Out:
# Generate 3 Short, Unqiue and Good Legal Research title names with the query -'Cheque Bounce'
#
# 1. "Exploring the Impact of Cheque Bounce on Commercial Transactions: A Legal Perspective"
# 2. "Navigating the Complexities of Cheque Bounce Law: A Comparative Analysis of Jurisdictions"
# 3. "Cheque Bounce: A Threat to Financial Stability? A Legal Analysis of Recent Trends and Developments"
#
# These are three unique and informative legal research title names related to the query "Cheque Bounce". Each title provides a clear focus on a specific aspect

# %% [markdown]
# ## Enhancing the Facts

# %%
fact='Loan pending with the bank'
def generate_enhanced_facts(fact):
    prompt = f"Enhance the fact -'{fact}' legally by adding 2-3 words"
    inputs = tokenizer(prompt, return_tensors="pt")
    generate_ids = model.generate(inputs.input_ids, max_length=50)
    return tokenizer.batch_decode(generate_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)[0]

# %%
print(generate_enhanced_facts(fact))
# Out:
# Enhance the fact -'Loan pending with the bank' legally by adding 2-3 words
#
# The loan is pending with the bank.
#
# To make it more legal and official, you can add the following words
